# %%
import numpy as np
import torch

from utils import saliency_map
from torchvision import transforms

# %load_ext autoreload
# %autoreload 2

# %%
model = torch.load('models/EfficientNetb0Att.model')

# %%
saliency_map(model, im_path='../DFirt/val/real/celeba_165398_100.jpg')
# Out:
# Type of manipulation:  Real
